# %%
import sys
sys.path.append('/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject')
from import_data import *

# %%
df_hmxb = HMXB_parameters()
df_falenga = falenga()
df_stellar_params = stellar_params()
df_photometric_params = photometric_params()
df_BJ = BailerJones()
df_kaper = HMXB_parameters_Kaper()

# %% [markdown]
# Parameters from Kaper (2001)

# %%
df_kaper
# Out:
#                id spectraltype  spinperiod    RV   Mob   Rob    Mx
# 0   2S0114+650(K)        B1 Ia      860.00  32.0  16.0   NaN   1.7
# 1      SMC X-1(K)        B0 Ib        0.71   NaN  17.2  15.0   1.6
# 2      LMC X-4(K)    O7 III-IV       13.50   NaN  15.8   8.0   1.5
# 3     Vela X-1(K)      B0.5 Ib      283.00  35.0  23.9  30.0   1.9
# 4      Cen X-3(K)  O6.5 II-III        4.84  42.0  18.4  11.0   1.1
# 5      GX301-2(K)     B1.5 Ia+      696.00   5.0  40.0   NaN   1.3
# 6    4U1538-52(K)       B0 Iab      529.00  85.0  16.4  15.0   1.1
# 7    4U1700-37(K)    O6.5 Iaf+         NaN  76.0  52.0  22.0   1.8
# 8    4U1907+09(K)    early B I      438.00   NaN   9.0   NaN   0.7
# 9      LMC X-1(K)     O7-9 III         NaN   NaN   NaN   NaN   7.0
# 10     Cyg X-1(K)     O9.7 Iab         NaN  20.0  17.8   NaN  10.0

# %% [markdown]
# Spectral types and photometric data with their sources

# %%
df_hmxb
# Out:
#                  id       ST                      ST_ref      ruwe       J  \
# 0        2S0114+650     B1Ia                Kaper (2001)  0.944642   8.597
# 1           SMC X-1     B0Ib  Van der Meer et al. (2007)  1.002890  13.445
# 2           LMC X-4    O8III  Van der Meer et al. (2007)  1.014480  14.586
# 3          Vela X-1   B0.5Ib        Barziv et al. (2001)  0.880197   5.833
# 4           Cen X-3  O6.5III  Van der Meer et al. (2007)  1.020704     NaN
# 5           GX301-2    B1Ia+         Kaper et al. (2006)  0.908531   6.717
# 6         4U1538-52     B0Ia                Kaper (2001)  0.985791  10.358
# 7         4U1700-37   O6Iaf+  Van der Meer et al. (2005)  0.808192   5.744
# 8         4U1907+09      O8I           Cox et al. (2005)  0.883853     NaN
# 9           LMC X-1    O8III                Kaper (2001)  0.996263  13.695
# 10          Cyg X-1  O9.7Iab                Kaper (2001)  0.967243   6.872
# ...

# %% [markdown]
# Photometric parameters from Martins et al. (2006)

# %%
df_photometric_params
# Out:
#          ST    Mu    Mb    Mv    Mj    Mh    Mk  (U-B)0  (B-V)0  (J-H)0  \
# 0       O3V -7.31 -6.15 -5.86 -5.19 -5.07 -4.98   -1.16   -0.28   -0.11
# 1       O4V -7.01 -5.85 -5.57 -4.91 -4.79 -4.69   -1.15   -0.28   -0.11
# 2       O5V -6.69 -5.54 -5.27 -4.60 -4.49 -4.39   -1.14   -0.28   -0.11
# 3     O5.5V -6.56 -5.42 -5.14 -4.48 -4.37 -4.27   -1.14   -0.28   -0.11
# 4       O6V -6.40 -5.27 -4.99 -4.34 -4.22 -4.13   -1.13   -0.28   -0.11
# 5     O6.5V -6.24 -5.12 -4.84 -4.19 -4.08 -3.98   -1.13   -0.27   -0.11
# 6       O7V -6.09 -4.97 -4.70 -4.05 -3.94 -3.84   -1.12   -0.27   -0.11
# 7     O7.5V -5.94 -4.83 -4.56 -3.91 -3.80 -3.70   -1.11   -0.27   -0.11
# 8       O8V -5.79 -4.68 -4.41 -3.78 -3.67 -3.57   -1.11   -0.27   -0.11
# 9     O8.5V -5.62 -4.52 -4.25 -3.62 -3.51 -3.41   -1.10   -0.27   -0.11
# 10      O9V -5.48 -4.38 -4.12 -3.48 -3.38 -3.28   -1.10   -0.27   -0.11
# 11    O9.5V -5.34 -4.25 -3.98 -3.36 -3.25 -3.15   -1.09   -0.26   -0.11
# ...

# %% [markdown]
# Stellar parameters from Martins et al. (2005a)

# %%
df_stellar_params
# Out:
#          ST   Teff  log(g_spec)    Mv    BC  log(L/Lsun)      R  M_spec  \
# 0       O3V  44852         3.92 -5.79 -4.05         5.84  13.80   57.95
# 1       O4V  42857         3.92 -5.50 -3.91         5.67  12.42   46.94
# 2       O5V  40862         3.92 -5.21 -3.77         5.49  11.20   38.08
# 3     O5.5V  39865         3.92 -5.07 -3.70         5.41  10.64   34.39
# 4       O6V  38867         3.92 -4.92 -3.62         5.32  10.11   30.98
# 5     O6.5V  37870         3.92 -4.77 -3.55         5.23   9.61   28.00
# 6       O7V  36872         3.92 -4.63 -3.47         5.14   9.15   25.29
# 7     O7.5V  35874         3.92 -4.48 -3.39         5.05   8.70   22.90
# 8       O8V  34877         3.92 -4.34 -3.30         4.96   8.29   20.76
# 9     O8.5V  33879         3.92 -4.19 -3.22         4.86   7.90   18.80
# 10      O9V  32882         3.92 -4.05 -3.13         4.77   7.53   17.08
# 11    O9.5V  31884         3.92 -3.90 -3.04         4.68   7.18   15.55
# ...

# %% [markdown]
# Data from Falenga et al. (2015)

# %%
df_falenga
# Out:
#                 id  semi_eclipse_angle  semi_eclipse_angle _err     a  a_err  \
# 0          LMC X-4                15.8                      0.8  14.2    0.2
# 1          Cen X-3                27.9                      0.3  20.2    0.4
# 2        4U1538-52                21.0                      1.0  22.0    1.0
# 3        4U1700-37                32.0                      1.0  35.0    1.0
# 4          SMC X-1                23.0                      2.0  27.9    0.7
# 5         Vela X-1                30.5                      0.1  59.6    0.7
# 6  IGR J18027−2016                31.0                      2.0  33.0    1.0
# 7    XTE J1855-026                32.0                      1.0  40.0    1.0
# 8     EXO 1722-363                26.0                      4.0  52.0    2.0
# 9     OAO 1657-415                20.9                      0.4  51.3    0.8
#
#       i  i_err  M_opt  M_opt_err  R_opt  R_opt_err    P_orbit  P_spin
# ...

# %% [markdown]
# Bailer Jones distances (2021)

# %%
df_BJ
# Out:
#               source_id               id          ra  ra_error  dec_error  \
# 0    524924310153249920       2S0114+650   19.511227  0.007461   0.008894
# 1   4686397666038575104          SMC X-1   19.271456  0.022771   0.021736
# 2   4660300345280168192          LMC X-4   83.206501  0.021186   0.021907
# 3   5620657678322625920         Vela X-1  135.528559  0.010860   0.012675
# 4   5337498593446516480          Cen X-3  170.312855  0.011634   0.011172
# 5   6054569565614460800          GX301-2  186.656451  0.012048   0.013341
# 6   5886085557746480000        4U1538-52  235.597298  0.010905   0.009432
# 7   5976382915813535232        4U1700-37  255.986566  0.021049   0.012138
# 8   4309225217336733824        4U1907+09  287.404730  0.059651   0.065512
# 9   4657637156283982336          LMC X-1   84.911809  0.016985   0.016223
# 10  2059383668236814720          Cyg X-1  299.590295  0.010938   0.013003
# 11  4255891924062617088    XTE J1855-026  283.876680  0.014236   0.014256
# ...
