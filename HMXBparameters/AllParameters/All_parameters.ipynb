# %% [markdown]
# # Collect all results

# %%
# import sys
# sys.path.append('/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject')
import pandas as pd
import numpy as np
from IPython.display import Markdown as md

# %%
power = 3
formatted_string = rf"10^{{{power}}}"
print(formatted_string)
# Out:
# 10^{3}

# %% [markdown]
# #### Function to make a markdown table of a pandas dataframe

# %%
def display_df(df2: pd.DataFrame, scientific_notation: bool = True, power: int = False, round_: bool = False, round_digits:int=1, return_md_text:bool=False, latex:bool=False, error_columns:list=False):
    """
    Displays a given dataframe in a nice way with better collumn names and units.
    """
    df = df2.copy()
    df_save = df2.copy()

    columns = {"R_true": (r"$R_{true}[R_{\odot}]$"),
               "R_true_err": r"$\delta R_{true} [R_{\odot}]$",
                "R_expected": r"$R_{expected}[R_{\odot}]$",
                "R_expected_err_high": r"$\delta_{high} R_{expected} [R_{\odot}]$",
                "R_expected_err_low": r"$\delta_{low} R_{expected} [R_{\odot}]$",
                "R_true/R_expected": r"$\frac{R_{true}}{R_{expected}}$",
                "R_ST_err": r"$\delta R_{ST} [R_{\odot}]$",
                "R_ST": r"$R_{ST} [R_{\odot}]$",
                "L_true": r"$L_{true}[L_{\odot}]$",
                "L_true_err_low": r"$\delta_{low} L_{true}[L_{\odot}]$",
                "L_true_err_high": r"$\delta_{high} L_{true}[L_{\odot}]$",
                "L_expected": r"$L_{expected}[L_{\odot}]$",
                "L_true/L_expected": r"$\frac{L_{true}}{L_{expected}}$",
                "Mopt": r"$M_{obs} [M_{\odot}]$",
                "Mopt_err": r"$\delta M_{obs} [M_{\odot}]$",
                "M_exp": r"$M_{BONN} [M_{\odot}]$",
                "M_exp_err": r"$\delta M_{BONN} [M_{\odot}]$",
                "M_ST": r"$M_{ST} [M_{\odot}]$",
                "M_ST_err": r"$\delta M_{ST} [M_{\odot}]$",
                "M_HRD": r"$M_{HRD} [M_{\odot}]$",
                "M_HRD_err": r"$\delta M_{HRD} [M_{\odot}]$",
                "ST": "Spec. Type",
                "ST_short": "Spec. Type (short)",
                "period": r"$P[days]$",
                "spinperiod": r"$P_{spin}[s]$",
                "eclipseduration": r"eclipseduration[units]",
                "RV": r"$v_{rad}[km s^{-1}]$",
                "Mob": r"$M_{ob}[M_{\odot}]$",
                "Mx": r"$M_{x} [M_{\odot}]$",
                "Rob": r"$R_{ob}[R_{\odot}]$",
                "Rx": r"$R_{x}[R_{\odot}]$",
                "parallax": r"$p'' ['']$",
                "errparallax": r"$\delta p''['']$",
                "distance": r"$d[pc]$",
                "distanceBJ": r"$d_{BJ}[pc]$",
                "luminosity": r"$L_{ob}[L_{\odot}]$",
                "(B-V)obs": r"$(B-V)_{obs}$",
                "(B-V)0": r"$(B-V)_{0}$",
                "BC": r"$BC_{v}$",
                "mv": r"$m_{v}$",
                "Teff": r"$T_{eff}[K]$",
                "Mv": r"$M_{v}$",
                "log(g_spec)": r"$log(g_{spec})$",
                "log(L/Lsun)": r"$log(\frac{L}{L_{\odot}}$",
                "M_spec": r"$M_{spec}$"}
    
    columns = { "R_true": r"$R_{true}[R_{\odot}]$",
                "Ropt": r"$R_{opt}[R_{\odot}]$",
                "R_expected": r"$R_{expected}[R_{\odot}]$",
                "R_ST": r"$R_{ST} [R_{\odot}]$",
                "R": r"$R_{spec} [R_{\odot}]$",

                "L_true": r"$L_{JH}[L_{\odot}]$",
                "LBV_true": r"$L_{BV} [L_{\odot}]$",
                "L_ST": r"$L_{expected}[L_{\odot}]$",
                "log(L/Lsun)": r"$^{10}$ log $(\frac{L}{L_{\odot}})$",

                "Mopt": r"$M_{obs} [M_{\odot}]$",
                "M_exp": r"$M_{BONN} [M_{\odot}]$",
                "M_ST": r"$M_{ST} [M_{\odot}]$",
                "M_HRD": r"$M_{HRD} [M_{\odot}]$",
                "M_spec": r"$M_{spec} [M_{\odot}]$",

                "Teff": r"$T_{eff}$ [K]",
                "Tmodel": r"$T_{model}$ [K]",
                "RL_fal": r"$R_{L,fal} [R_{\odot}]$",

                "RL_q": r"$R_{L,q} [R_{\odot}]$",
                "RL_g": r"$R_{L,g} [R_{\odot}]$",

                "Mv": r"$M_{v}$",
                "(J-H)0": r"$(J-H)_{0}$",
                "(B-V)0": r"$(B-V)_{0}$",
                "Mh": r"$M_{h}$",
                "BCh": r"$BC_{h}$",
                "BCv": r"$BC_{v}$",

                "r_med_photogeo": r"$d_{BJ} [pc]$",

                "X_rayFlux_SWIFTXRT": r"$F_{swift, X-ray}$",

                # Falenga table
                "Orbital period": r"$P_{orb}$",
                "Orbital period error": r"$\delta P_{orb}$",
                "ax sin i": r"$a_{x} \cdot sin(i)$",
                "ST": "Spec. Type"
                }

    if power:
        # Identify columns with numerical values
        numeric_cols = df.select_dtypes(include=[np.number]).columns
        # Scale down
        for col in numeric_cols:
            df[col] /= 10**power
            df_save[col] /= 10**power

    # Scientific notation
    if scientific_notation:
        df = df.map(lambda x: "*" + "%.2E" % x if isinstance(x, (int, float, np.floating)) else x)
        df_save = df_save.map(lambda x: "*" + "%.2E" % x if isinstance(x, (int, float, np.floating)) else x)


    # Round
    if round_:
        df = df.map(lambda x: round(x, round_digits) if isinstance(x, (int, float, np.floating)) else x)
        df_save = df_save.map(lambda x: round(x, round_digits) if isinstance(x, (int, float, np.floating)) else x)

    if error_columns:
        # Write error columns like 1
        for error_column in error_columns:
            # For asymmetric errors
            if len(error_column) == 3:
                # Calculate the formatted error string for each row
                error_strings = df_save.apply(lambda row: f"${row[error_column[0]]}^{{+{row[error_column[1]]}}}_{{-{row[error_column[2]]}}}$", axis=1)
                
                # Create a new column in the DataFrame with the formatted error strings
                df[error_column[0]] = error_strings

            # For symmetric errors
            if len(error_column) == 2:
                # Calculate the formatted error string for each row
                error_strings = df_save.apply(lambda row: f"${row[error_column[0]]} \pm {{{row[error_column[1]]}}}$", axis=1)
                
                # Create a new column in the DataFrame with the formatted error strings
                df[error_column[0]] = error_strings

        # Remove the error columns
        df.drop(columns=error_column[1:], inplace=True)

    # Rename columns
    df = df.rename(columns=columns)

    # Also add the power divided out to the column name
    if power:
        # Update column names to reflect the scaling
        df.columns = [(r'$' + col.replace('$', '') + rf"(10^{{{power}}})$") if col != 'id' else col for col in df.columns]

    # To markdown
    markdown_text = df.to_markdown(index=False, tablefmt="pipe")

    # Remove '*' from text
    markdown_text = markdown_text.replace('*', '')

    if latex:
        return print(df.to_latex(index=False, float_format="{:.0f}".format, na_rep='--'))
    if return_md_text:
        return markdown_text
    else:
        return md(markdown_text)

# %% [markdown]
# #### Import all parameters

# %%
df_AllParams = pd.read_csv("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/results/ALLPARAMETERS2.csv")
objects = df_AllParams.id.tolist()

# %% [markdown]
# Column names:
# - id:           Name of the object
# - ST:           Spectral type <br><br>
# - Mopt:         Mass based on orbital parameters
# - M_exp:        Mass determined with the BONNSAI models
# - M_HRD:        Mass determined with the Chen 2015 evolutionary tracks
# - M_ST:         Mass based on martins models and ST <br><br>
# - Ropt:         Radius based on $\theta_{e}$ **=R_true**
# - R_expected:   From L=4piR2sigmaT4
# - R_ST:         Radius based on Martins models and spectral type <br><br>
# - L_true:       Photometric luminosity
# - L_ST:         Luminosity based on martins models <br><br>
# - Teff:         Effective temperature based on martins models and ST
# - Teff_mod:     Model Teff <br><br>
# - P_orbit:      Orbital period
# - P_spin:       Spin period of compact object
# - Mx:           Mass of compact object

# %% [markdown]
# #### Markdown tables

# %% [markdown]
# ##### Important parameters

# %%
df_Table = df_AllParams[['id', 'Mopt', 'M_exp', 'M_HRD', 'M_ST', 'Ropt', 'R_expected', 'R_ST', 'L_true', 'L_ST', 'Teff']]
display_df(df_Table, scientific_notation=False, round_=True, round_digits=0, return_md_text=False)
# Out:
# | id            |   $M_{obs} [M_{\odot}]$ |   $M_{BONN} [M_{\odot}]$ |   $M_{HRD} [M_{\odot}]$ |   $M_{ST} [M_{\odot}]$ |   $R_{opt}[R_{\odot}]$ |   $R_{expected}[R_{\odot}]$ |   $R_{ST} [R_{\odot}]$ |   $L_{true}[L_{\odot}]$ |   $L_{expected}[L_{\odot}]$ |   $T_{eff}$ [K] |
# |:--------------|------------------------:|-------------------------:|------------------------:|-----------------------:|-----------------------:|----------------------------:|-----------------------:|------------------------:|----------------------------:|----------------:|
# | SMC X-1       |                      18 |                       31 |                      33 |                     26 |                     15 |                          21 |                     22 |                  300230 |                      338844 |           29558 |
# | LMC X-4       |                      18 |                       20 |                      21 |                     25 |                      7 |                           8 |                     14 |                   79733 |                      223872 |           33961 |
# | Vela X-1      |                      26 |                       35 |                      36 |                     24 |                     29 |                          26 |                     23 |                  396729 |                      309030 |           28653 |
# | Cen X-3       |                      24 |                       46 |                      48 |                     32 |                     11 |                          10 |                     14 |                  158843 |                      346737 |           37134 |
# | 4U1538-52     |                      16 |                       20 |                      19 |                     26 |                     13 |                          11 |                     22 |                   81089 |                      338844 |           29558 |
# | 4U1700-37     |                      46 |                       44 |                      45 |                     44 |                     22 |                          17 |                     20 |                  501427 |                      645654 |           36801 |
# | XTE J1855-026 |                      21 |                       22 |                      23 |                     26 |                     22 |                          13 |                     22 |                  123869 |                      338844 |           29558 |

# %% [markdown]
# ##### Mass

# %%
df_Table = df_AllParams[['id', 'Mopt', 'M_exp', 'M_HRD', 'M_ST']]
display_df(df_Table, scientific_notation=False, round_=True, round_digits=0, return_md_text=False, latex=True)
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# id & $M_{obs} [M_{\odot}]$ & $M_{BONN} [M_{\odot}]$ & $M_{HRD} [M_{\odot}]$ & $M_{ST} [M_{\odot}]$ \\
# \midrule
# SMC X-1 & 18 & 31 & 33 & 26 \\
# LMC X-4 & 18 & 20 & 21 & 25 \\
# Vela X-1 & 26 & 35 & 36 & 24 \\
# Cen X-3 & 24 & 46 & 48 & 32 \\
# 4U1538-52 & 16 & 20 & 19 & 26 \\
# 4U1700-37 & 46 & 44 & 45 & 44 \\
# XTE J1855-026 & 21 & 22 & 23 & 26 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ##### Radius

# %%
df_Table = df_AllParams[['id', 'Ropt', 'R_expected', 'R_ST']]
display_df(df_Table, scientific_notation=False, round_=True, round_digits=0, return_md_text=False, latex=False)
# Out:
# | id            |   $R_{opt}[R_{\odot}]$ |   $R_{expected}[R_{\odot}]$ |   $R_{ST} [R_{\odot}]$ |
# |:--------------|-----------------------:|----------------------------:|-----------------------:|
# | SMC X-1       |                     15 |                          21 |                     22 |
# | LMC X-4       |                      7 |                           8 |                     14 |
# | Vela X-1      |                     29 |                          26 |                     23 |
# | Cen X-3       |                     11 |                          10 |                     14 |
# | 4U1538-52     |                     13 |                          11 |                     22 |
# | 4U1700-37     |                     22 |                          17 |                     20 |
# | XTE J1855-026 |                     22 |                          13 |                     22 |

# %% [markdown]
# ##### Luminosity

# %%
df_Table = df_AllParams[['id', 'L_true', 'L_true_err_high', 'L_true_err_low','LBV_true', 'L_ST']]
display_df(df_Table, scientific_notation=False, round_=True, round_digits=1, power=4,
           return_md_text=False, latex=True, error_columns=[['L_true', 'L_true_err_high', 'L_true_err_low']])
# Out:
# \begin{tabular}{llrr}
# \toprule
# id & $L_{JH}[L_{\odot}](10^{4})$ & $L_{BV} [L_{\odot}](10^{4})$ & $L_{expected}[L_{\odot}](10^{4})$ \\
# \midrule
# SMC X-1 & $30.0^{+2.9}_{-4.8}$ & 27 & 34 \\
# LMC X-4 & $8.0^{+1.5}_{-1.5}$ & 15 & 22 \\
# Vela X-1 & $39.7^{+4.6}_{-4.8}$ & 59 & 31 \\
# Cen X-3 & $15.9^{+3.6}_{-2.6}$ & 15 & 35 \\
# 4U1538-52 & $8.1^{+1.3}_{-1.5}$ & 21 & 34 \\
# 4U1700-37 & $50.1^{+7.1}_{-6.0}$ & 50 & 65 \\
# XTE J1855-026 & $12.4^{+3.0}_{-2.9}$ & 55 & 34 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ##### Temperature

# %%
df_Table = df_AllParams[['id', 'Teff']]
display_df(df_Table, scientific_notation=False, round_=True, round_digits=0, return_md_text=False)
# Out:
# | id            |   $T_{eff}$ [K] |
# |:--------------|----------------:|
# | SMC X-1       |           29558 |
# | LMC X-4       |           33961 |
# | Vela X-1      |           28653 |
# | Cen X-3       |           37134 |
# | 4U1538-52     |           29558 |
# | 4U1700-37     |           36801 |
# | XTE J1855-026 |           29558 |

# %% [markdown]
# ##### Roche lobe radius

# %% [markdown]
# - RL_fal:       Roche lobe radius from Falenga et al. 2015
# - RL_q:         Roche lobe radius based on q and a parameters
# - RL_g:         Roche lobe radius based on q and g parameters

# %%
df_Table = df_AllParams[['id', 'RL_fal', 'RL_q', 'RL_g']]
display_df(df_Table, scientific_notation=False, round_=True, round_digits=0, return_md_text=False, latex=False)
# Out:
# | id            |   $R_{L,fal} [R_{\odot}]$ |   $R_{L,q} [R_{\odot}]$ |   $R_{L,g} [R_{\odot}]$ |
# |:--------------|--------------------------:|------------------------:|------------------------:|
# | SMC X-1       |                        17 |                      17 |                      17 |
# | LMC X-4       |                         8 |                       8 |                       8 |
# | Vela X-1      |                        35 |                      35 |                      36 |
# | Cen X-3       |                        13 |                      12 |                      12 |
# | 4U1538-52     |                        12 |                      13 |                      14 |
# | 4U1700-37     |                        24 |                      22 |                      23 |
# | XTE J1855-026 |                        25 |                      24 |                      25 |

# %% [markdown]
# #### Data

# %% [markdown]
# ##### Photometric data

# %%
df_HMXB = pd.read_excel("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/HMXBparameters.xlsx")
df_HMXB = df_HMXB[df_HMXB.id.isin(objects)][["id", "ST", "J", "H", "K", "JHK_err", "B", "V"]]
display_df(df_HMXB, scientific_notation=False, round_=True, round_digits=2, power=False,
           return_md_text=False, latex=False, error_columns=[["J", "JHK_err"], ["H", "JHK_err"], ["K", "JHK_err"]])
# Out:
# | id            | Spec. Type   | J                  | H                  | K                  |     B |     V |
# |:--------------|:-------------|:-------------------|:-------------------|:-------------------|------:|------:|
# | SMC X-1       | B0Ib         | $13.45 \pm {0.03}$ | $13.51 \pm {0.03}$ | $13.47 \pm {0.03}$ | 13    | 13.15 |
# | LMC X-4       | O8III        | $14.59 \pm {0.03}$ | $14.78 \pm {0.03}$ | $14.75 \pm {0.03}$ | 13.9  | 14    |
# | Vela X-1      | B0.5Ib       | $5.83 \pm {0.03}$  | $5.71 \pm {0.03}$  | $5.6 \pm {0.03}$   |  7.37 |  6.87 |
# | Cen X-3       | O6.5III      | $10.74 \pm {0.03}$ | $10.31 \pm {0.03}$ | $10.09 \pm {0.03}$ | 14.4  | 13.4  |
# | 4U1538-52     | B0Ia         | $10.36 \pm {0.03}$ | $9.91 \pm {0.03}$  | $9.68 \pm {0.03}$  | 16.3  | 14.5  |
# | 4U1700-37     | O6Iaf+       | $5.74 \pm {0.03}$  | $5.64 \pm {0.03}$  | $5.5 \pm {0.03}$   |  6.78 |  6.51 |
# | XTE J1855-026 | B0Iaep       | $10.56 \pm {0.03}$ | $10.09 \pm {0.03}$ | $9.8 \pm {0.03}$   | 16.45 | 14.51 |

# %% [markdown]
# ##### Stellar parameters (Model)

# %%
df_StellarParam = pd.read_excel("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/StellarParam.xlsx")
print(df_StellarParam.columns)
df_StellarParam = df_StellarParam[["ST", "Teff", "log(L/Lsun)", "R", "M_spec"]]
display_df(df_StellarParam, scientific_notation=False, round_=False, round_digits=0, return_md_text=False, latex=False)
# Out:
# Index(['ST', 'Teff', 'log(g_spec)', 'Mv', 'BC', 'log(L/Lsun)', 'R', 'M_spec',
#        'logq0', 'logq1', 'logQ0', 'logQ1'],
#       dtype='object')
# | ST      |   $T_{eff}$ [K] |   $^{10}$ log $(\frac{L}{L_{\odot}})$ |   $R_{spec} [R_{\odot}]$ |   $M_{spec} [M_{\odot}]$ |
# |:--------|----------------:|--------------------------------------:|-------------------------:|-------------------------:|
# | O3V     |           44852 |                                  5.84 |                    13.8  |                    57.95 |
# | O4V     |           42857 |                                  5.67 |                    12.42 |                    46.94 |
# | O5V     |           40862 |                                  5.49 |                    11.2  |                    38.08 |
# | O5.5V   |           39865 |                                  5.41 |                    10.64 |                    34.39 |
# | O6V     |           38867 |                                  5.32 |                    10.11 |                    30.98 |
# | O6.5V   |           37870 |                                  5.23 |                     9.61 |                    28    |
# | O7V     |           36872 |                                  5.14 |                     9.15 |                    25.29 |
# | O7.5V   |           35874 |                                  5.05 |                     8.7  |                    22.9  |
# | O8V     |           34877 |                                  4.96 |                     8.29 |                    20.76 |
# | O8.5V   |           33879 |                                  4.86 |                     7.9  |                    18.8  |
# | O9V     |           32882 |                                  4.77 |                     7.53 |                    17.08 |
# | O9.5V   |           31884 |                                  4.68 |                     7.18 |                    15.55 |
# | O3III   |           44537 |                                  5.96 |                    16.19 |                    55.95 |
# | O4III   |           42422 |                                  5.85 |                    15.61 |                    47.43 |
# | O5III   |           40307 |                                  5.73 |                    15.07 |                    40.43 |
# | O5.5III |           39249 |                                  5.67 |                    14.82 |                    37.35 |
# | O6III   |           38192 |                                  5.61 |                    14.58 |                    34.53 |
# | O6.5III |           37134 |                                  5.54 |                    14.36 |                    31.96 |
# | O7III   |           36077 |                                  5.48 |                    14.14 |                    29.59 |
# | O7.5III |           35019 |                                  5.42 |                    13.93 |                    27.45 |
# | O8III   |           33961 |                                  5.35 |                    13.74 |                    25.49 |
# | O8.5III |           32904 |                                  5.28 |                    13.55 |                    23.68 |
# | O9III   |           31846 |                                  5.21 |                    13.38 |                    22.04 |
# | O9.5III |           30789 |                                  5.15 |                    13.22 |                    20.55 |
# | O3I     |           42233 |                                  5.99 |                    18.56 |                    67.53 |
# | O4I     |           40422 |                                  5.93 |                    18.99 |                    58.54 |
# | O5I     |           38612 |                                  5.87 |                    19.45 |                    50.72 |
# | O5.5I   |           37706 |                                  5.84 |                    19.7  |                    47.25 |
# | O6I     |           36801 |                                  5.81 |                    19.95 |                    44.1  |
# | O6.5I   |           35895 |                                  5.78 |                    20.22 |                    41.2  |
# | O7I     |           34990 |                                  5.75 |                    20.49 |                    38.44 |
# | O7.5I   |           34084 |                                  5.72 |                    20.79 |                    36    |
# | O8I     |           33179 |                                  5.68 |                    21.1  |                    33.72 |
# | O8.5I   |           32274 |                                  5.65 |                    21.41 |                    31.54 |
# | O9I     |           31368 |                                  5.61 |                    21.76 |                    29.63 |
# | O9.5I   |           30463 |                                  5.57 |                    22.11 |                    27.83 |

# %% [markdown]
# ##### Photometric parameters (model)

# %%
df_PhotoParam = pd.read_excel("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/PhotometricParam.xlsx")
df_PhotoParam = df_PhotoParam[["ST", "Mv", "Mh", "(B-V)0", "(J-H)0", "BCv", "BCh"]]
display_df(pd.merge(df_StellarParam, df_PhotoParam, on='ST'), scientific_notation=False, round_=False, round_digits=0, return_md_text=False, latex=False)
# Out:
# | ST      |   $T_{eff}$ [K] |   $^{10}$ log $(\frac{L}{L_{\odot}})$ |   $R_{spec} [R_{\odot}]$ |   $M_{spec} [M_{\odot}]$ |   $M_{v}$ |   $M_{h}$ |   $(B-V)_{0}$ |   $(J-H)_{0}$ |   $BC_{v}$ |   $BC_{h}$ |
# |:--------|----------------:|--------------------------------------:|-------------------------:|-------------------------:|----------:|----------:|--------------:|--------------:|-----------:|-----------:|
# | O3V     |           44852 |                                  5.84 |                    13.8  |                    57.95 |     -5.86 |     -5.07 |         -0.28 |         -0.11 |      -3.99 |      -4.78 |
# | O4V     |           42857 |                                  5.67 |                    12.42 |                    46.94 |     -5.57 |     -4.79 |         -0.28 |         -0.11 |      -3.85 |      -4.63 |
# | O5V     |           40862 |                                  5.49 |                    11.2  |                    38.08 |     -5.27 |     -4.49 |         -0.28 |         -0.11 |      -3.71 |      -4.48 |
# | O5.5V   |           39865 |                                  5.41 |                    10.64 |                    34.39 |     -5.14 |     -4.37 |         -0.28 |         -0.11 |      -3.64 |      -4.4  |
# | O6V     |           38867 |                                  5.32 |                    10.11 |                    30.98 |     -4.99 |     -4.22 |         -0.28 |         -0.11 |      -3.56 |      -4.33 |
# | O6.5V   |           37870 |                                  5.23 |                     9.61 |                    28    |     -4.84 |     -4.08 |         -0.27 |         -0.11 |      -3.48 |      -4.24 |
# | O7V     |           36872 |                                  5.14 |                     9.15 |                    25.29 |     -4.7  |     -3.94 |         -0.27 |         -0.11 |      -3.4  |      -4.16 |
# | O7.5V   |           35874 |                                  5.05 |                     8.7  |                    22.9  |     -4.56 |     -3.8  |         -0.27 |         -0.11 |      -3.32 |      -4.07 |
# | O8V     |           34877 |                                  4.96 |                     8.29 |                    20.76 |     -4.41 |     -3.67 |         -0.27 |         -0.11 |      -3.24 |      -3.98 |
# | O8.5V   |           33879 |                                  4.86 |                     7.9  |                    18.8  |     -4.25 |     -3.51 |         -0.27 |         -0.11 |      -3.15 |      -3.89 |
# | O9V     |           32882 |                                  4.77 |                     7.53 |                    17.08 |     -4.12 |     -3.38 |         -0.27 |         -0.11 |      -3.06 |      -3.8  |
# | O9.5V   |           31884 |                                  4.68 |                     7.18 |                    15.55 |     -3.98 |     -3.25 |         -0.26 |         -0.11 |      -2.97 |      -3.7  |
# | O3III   |           44537 |                                  5.96 |                    16.19 |                    55.95 |     -6.18 |     -5.4  |         -0.28 |         -0.11 |      -3.97 |      -4.75 |
# | O4III   |           42422 |                                  5.85 |                    15.61 |                    47.43 |     -6.05 |     -5.27 |         -0.28 |         -0.11 |      -3.82 |      -4.6  |
# | O5III   |           40307 |                                  5.73 |                    15.07 |                    40.43 |     -5.91 |     -5.14 |         -0.28 |         -0.11 |      -3.67 |      -4.44 |
# | O5.5III |           39249 |                                  5.67 |                    14.82 |                    37.35 |     -5.84 |     -5.07 |         -0.28 |         -0.11 |      -3.59 |      -4.36 |
# | O6III   |           38192 |                                  5.61 |                    14.58 |                    34.53 |     -5.77 |     -5    |         -0.27 |         -0.11 |      -3.51 |      -4.27 |
# | O6.5III |           37134 |                                  5.54 |                    14.36 |                    31.96 |     -5.68 |     -4.92 |         -0.27 |         -0.11 |      -3.42 |      -4.18 |
# | O7III   |           36077 |                                  5.48 |                    14.14 |                    29.59 |     -5.61 |     -4.86 |         -0.27 |         -0.11 |      -3.34 |      -4.09 |
# | O7.5III |           35019 |                                  5.42 |                    13.93 |                    27.45 |     -5.55 |     -4.8  |         -0.27 |         -0.11 |      -3.25 |      -4    |
# | O8III   |           33961 |                                  5.35 |                    13.74 |                    25.49 |     -5.47 |     -4.72 |         -0.27 |         -0.11 |      -3.16 |      -3.9  |
# | O8.5III |           32904 |                                  5.28 |                    13.55 |                    23.68 |     -5.39 |     -4.65 |         -0.27 |         -0.11 |      -3.06 |      -3.8  |
# | O9III   |           31846 |                                  5.21 |                    13.38 |                    22.04 |     -5.31 |     -4.58 |         -0.26 |         -0.11 |      -2.96 |      -3.7  |
# | O9.5III |           30789 |                                  5.15 |                    13.22 |                    20.55 |     -5.26 |     -4.53 |         -0.26 |         -0.11 |      -2.86 |      -3.59 |
# | O3I     |           42233 |                                  5.99 |                    18.56 |                    67.53 |     -6.42 |     -5.64 |         -0.28 |         -0.11 |      -3.81 |      -4.59 |
# | O4I     |           40422 |                                  5.93 |                    18.99 |                    58.54 |     -6.4  |     -5.63 |         -0.28 |         -0.11 |      -3.68 |      -4.45 |
# | O5I     |           38612 |                                  5.87 |                    19.45 |                    50.72 |     -6.39 |     -5.62 |         -0.28 |         -0.11 |      -3.54 |      -4.3  |
# | O5.5I   |           37706 |                                  5.84 |                    19.7  |                    47.25 |     -6.38 |     -5.62 |         -0.27 |         -0.11 |      -3.47 |      -4.23 |
# | O6I     |           36801 |                                  5.81 |                    19.95 |                    44.1  |     -6.38 |     -5.62 |         -0.27 |         -0.11 |      -3.4  |      -4.15 |
# | O6.5I   |           35895 |                                  5.78 |                    20.22 |                    41.2  |     -6.38 |     -5.62 |         -0.27 |         -0.11 |      -3.32 |      -4.08 |
# | O7I     |           34990 |                                  5.75 |                    20.49 |                    38.44 |     -6.38 |     -5.63 |         -0.27 |         -0.11 |      -3.24 |      -4    |
# | O7.5I   |           34084 |                                  5.72 |                    20.79 |                    36    |     -6.38 |     -5.64 |         -0.27 |         -0.11 |      -3.17 |      -3.91 |
# | O8I     |           33179 |                                  5.68 |                    21.1  |                    33.72 |     -6.36 |     -5.62 |         -0.27 |         -0.11 |      -3.09 |      -3.83 |
# | O8.5I   |           32274 |                                  5.65 |                    21.41 |                    31.54 |     -6.37 |     -5.63 |         -0.26 |         -0.11 |      -3    |      -3.74 |
# | O9I     |           31368 |                                  5.61 |                    21.76 |                    29.63 |     -6.36 |     -5.62 |         -0.26 |         -0.11 |      -2.92 |      -3.65 |
# | O9.5I   |           30463 |                                  5.57 |                    22.11 |                    27.83 |     -6.34 |     -5.62 |         -0.26 |         -0.11 |      -2.83 |      -3.56 |

# %% [markdown]
# ##### GAIA $E(G_{rp}-G_{bp})$

# %%
# df_idConverter = pd.read_excel("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/id_converter.xlsx")
# df_idConverter['source_id'] = df_idConverter['source_id'].astype(int)
df_GAIAColorExcess = pd.read_csv("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/GAIA_ColorExcess.csv")
# df_GAIAColorExcess = pd.merge(df_idConverter, df_GAIAColorExcess, on='source_id')
df_GAIAColorExcess = df_GAIAColorExcess[df_GAIAColorExcess.id.isin(objects)][['id', 'bp_rp', 'ebpminrp_gspphot']]
# df_GAIAColorExcess.to_csv("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/GAIA_ColorExcess.csv")
display_df(df_GAIAColorExcess, scientific_notation=False, round_=False, round_digits=0, return_md_text=False)
# Out:
# | id            |     bp_rp |   ebpminrp_gspphot |
# |:--------------|----------:|-------------------:|
# | SMC X-1       | -0.239637 |             0.1928 |
# | LMC X-4       | -0.345118 |             0.0676 |
# | Vela X-1      |  0.720456 |             0.9958 |
# | Cen X-3       |  1.60877  |             1.9264 |
# | 4U1538-52     |  2.53679  |             1.8552 |
# | 4U1700-37     |  0.487367 |           nan      |
# | XTE J1855-026 |  2.46699  |             1.8784 |

# %% [markdown]
# ##### X-ray flux

# %%
df_Xray = pd.read_excel("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/X_ray_lum.xlsx")
df_Xray = df_Xray[df_Xray.id.isin(objects)]
display_df(pd.merge(df_AllParams[["id", "r_med_photogeo"]], df_Xray[['id', 'X_rayFlux_SWIFTXRT']], on='id'), scientific_notation=False, 
           round_=False, round_digits=0, return_md_text=False, latex=False)
# Out:
# | id            |   $d_{BJ} [pc]$ |   $F_{swift, X-ray}$ |
# |:--------------|----------------:|---------------------:|
# | SMC X-1       |        62440    |                992.4 |
# | LMC X-4       |        48590    |                  0   |
# | Vela X-1      |         1969.48 |               1759   |
# | Cen X-3       |         6752.49 |               3861   |
# | 4U1538-52     |         5535.36 |                271.9 |
# | 4U1700-37     |         1513.99 |               1157   |
# | XTE J1855-026 |         7386.87 |                218.7 |

# %% [markdown]
# ##### Falenga tables

# %%
df_Falenga1 = pd.read_excel("/mnt/c/Users/luukv/Documenten/NatuurSterrkenkundeMasterProject/CodeMP/MasterProject/tables/FalengaTable1.xlsx").rename(columns={'Source': 'id'})
df_Falenga1 = df_Falenga1[df_Falenga1.id.isin(objects)]
display_df(df_Falenga1, scientific_notation=False, 
           round_=False, round_digits=0, return_md_text=False, latex=False)
# Out:
# | id            | Type         |   Orbital epoch |   Orbital epoch error |   $P_{orb}$ |   $\delta P_{orb}$ | $P_{s}$   | $\dot{P}_{orb}/P_{obs}$   | $a_{x} \cdot sin(i)$   | e          | $\omega$   |
# |:--------------|:-------------|----------------:|----------------------:|------------:|-------------------:|:----------|:--------------------------|:-----------------------|:-----------|:-----------|
# | LMC X-4       | O8III        |         51110.9 |               0.0001  |     1.4084  |            2.6e-07 | 13.5      | −0.98(7)                  | 26.343(16)             | 0.006(2)   | -          |
# | Cen X-3       | O(6-7)II-III |         50506.8 |               7e-06   |     2.08711 |            7e-09   | 4.8       | −1.799(2)                 | 39.6612(9)             | <0.0016    | -          |
# | 4U1700-37     | O6.5Iaf+     |         48900.4 |               0.015   |     3.41158 |            2.7e-05 | -         | −3.3(6)                   | 48-82                  | -j         | 49(11)     |
# | 4U1538-52     | B0.2Ia       |         52851.3 |               0.01    |     3.72838 |            1.1e-05 | 526.8     | -                         | 53.1(1.5)              | 0.18(1)    | 40(12)     |
# | SMC X-1       | B0sg         |         50324.7 |               8e-06   |     3.89221 |            4e-08   | 0.71      | −3.402(7)                 | 53.4876(9)             | 0.00089(6) | 166(12)    |
# | XTE J1855-026 | B0Iaep       |         51495.2 |               0.02    |     6.0724  |            0.0009  | 360.7     | -                         | 80.5(1.4)              | 0.04(2)    | 226(15)    |
# | Vela X-1      | B0.5Iae      |         48895.2 |               0.00012 |     8.96437 |            4e-05   | 283.2     | -                         | 113.89(13)             | 0.0898(12) | 152.59(92) |
